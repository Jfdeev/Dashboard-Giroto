# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
# Aggregate the data by calculating the mean of 'Depression' for each 'Gender'
aggregated_data = df.groupby('Gender', as_index=False)['Depression'].mean()

# Plot the aggregated data
sns.barplot(data=aggregated_data, x='Gender', y='Depression')
# Out:
# <Axes: xlabel='Gender', ylabel='Depression'>

# %%
import matplotlib.pyplot as plt

df.groupby('Age')['Depression'].mean().plot(kind='bar')

plt.title('Average Depression by Age')
plt.xlabel('Age')
plt.ylabel('Average Depression')
plt.show()

# %%
df.groupby('Academic Pressure')['Depression'].mean().plot(kind='bar')
plt.title('Average Depression by Academic Pressure')
plt.xlabel('Academic Pressure')
plt.ylabel('Average Depression')
plt.show()

# %%
df.groupby('Sleep Duration')['Depression'].mean().plot(kind='bar')
plt.title('Average Depression by Sleep Duration')
plt.xlabel('Sleep Duration')
plt.ylabel('Average Depression')
plt.show()
